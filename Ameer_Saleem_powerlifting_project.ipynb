# %% [markdown]
# <a href="https://colab.research.google.com/github/AmeerAliSaleem/powerlifting/blob/main/Ameer_Saleem_powerlifting_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # u2001820 Powerlifting project
# ---
#
# We aim to investigate the powerlifting dataset available on <a href="https://www.kaggle.com/datasets/open-powerlifting/powerlifting-database">Kaggle</a>. Kaggle also provides some extra info regarding the columns of the dataset.

# %%
# imports
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data imports and preprocessing

# %%
df = pd.read_csv("openpowerlifting.csv")

# %%
df.head()
# Out:
#               Name Sex Event Equipment   Age AgeClass Division  BodyweightKg  \
# 0     Abbie Murphy   F   SBD     Wraps  29.0    24-34     F-OR          59.8
# 1      Abbie Tuong   F   SBD     Wraps  29.0    24-34     F-OR          58.5
# 2   Ainslee Hooper   F     B       Raw  40.0    40-44     F-OR          55.4
# 3  Amy Moldenhauer   F   SBD     Wraps  23.0    20-23     F-OR          60.0
# 4     Andrea Rowan   F   SBD     Wraps  45.0    45-49     F-OR         104.0
#
#   WeightClassKg  Squat1Kg  ...  McCulloch  Glossbrenner  IPFPoints  Tested  \
# 0            60      80.0  ...     324.16        286.42     511.15     NaN
# 1            60     100.0  ...     378.07        334.16     595.65     NaN
# 2            56       NaN  ...      38.56         34.12     313.97     NaN
# 3            60    -105.0  ...     345.61        305.37     547.04     NaN
# 4           110     120.0  ...     338.91        274.56     550.08     NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69838 entries, 0 to 69837
# Data columns (total 37 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             69838 non-null  object
#  1   Sex              69838 non-null  object
#  2   Event            69838 non-null  object
#  3   Equipment        69838 non-null  object
#  4   Age              66411 non-null  float64
#  5   AgeClass         66846 non-null  object
#  6   Division         69648 non-null  object
#  7   BodyweightKg     69520 non-null  float64
#  8   WeightClassKg    69571 non-null  object
#  9   Squat1Kg         38088 non-null  float64
#  10  Squat2Kg         37604 non-null  float64
#  11  Squat3Kg         36147 non-null  float64
#  12  Squat4Kg         292 non-null    float64
#  13  Best3SquatKg     45558 non-null  float64
#  14  Bench1Kg         53126 non-null  float64
#  15  Bench2Kg         52629 non-null  float64
# ...

# %% [markdown]
# ## Questions to investigate
# 1) Which lifts are the best between males and females?
#
# 2) What effect does age tend to have on the participant's lifting capacity?
#
# 3) Which countries harbour the 'best' athletes?
#
# 4) How many attempts should a lifter make in order to maximise performance?
